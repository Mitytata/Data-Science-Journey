# %% [markdown]
# # Titanic Survival Prediction

# %% [markdown]
# ## Import the necessssary libraries

# %%
#data analysis libraries
import pandas as pd
import numpy as np

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import the data, explore and wrangle

# %%
#imported both test and train data directly from github account(public)

test_data = "https://raw.githubusercontent.com/Mitytata/Data-Science-Journey/main/test.csv"
train_data = "https://raw.githubusercontent.com/Mitytata/Data-Science-Journey/main/train.csv"

test = pd.read_csv(test_data)
train = pd.read_csv(train_data)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# remove passengerId and Name colum 
train = train[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Survived','Ticket','Cabin','Embarked']]
train.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare  Survived            Ticket  \
# 0       3    male  22.0      1      0   7.2500         0         A/5 21171
# 1       1  female  38.0      1      0  71.2833         1          PC 17599
# 2       3  female  26.0      0      0   7.9250         1  STON/O2. 3101282
# 3       1  female  35.0      1      0  53.1000         1            113803
# 4       3    male  35.0      0      0   8.0500         0            373450
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
# remove ticket columns as tickets looks to have been randomly assigned to passengers 
train = train[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Survived','Fare','Cabin','Embarked']]
train.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch  Survived     Fare Cabin Embarked
# 0       3    male  22.0      1      0         0   7.2500   NaN        S
# 1       1  female  38.0      1      0         1  71.2833   C85        C
# 2       3  female  26.0      0      0         1   7.9250   NaN        S
# 3       1  female  35.0      1      0         1  53.1000  C123        S
# 4       3    male  35.0      0      0         0   8.0500   NaN        S

# %%
# remove embarked - this has no effect on whether a passenger survived or not 
train = train[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Survived','Fare','Cabin']]
train.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch  Survived     Fare Cabin
# 0       3    male  22.0      1      0         0   7.2500   NaN
# 1       1  female  38.0      1      0         1  71.2833   C85
# 2       3  female  26.0      0      0         1   7.9250   NaN
# 3       1  female  35.0      1      0         1  53.1000  C123
# 4       3    male  35.0      0      0         0   8.0500   NaN

# %%
#brief info about the dataframe to determine if any column needs to be removed
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Survived  891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
# remove cabin column as it only has 204 values, the rest will be non values 
train = train[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp','Parch', 'Fare']]
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
# remove  fare column - this relates to the Pclass 
train = train[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp','Parch']]
train.head(15)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch
# 0          0       3    male  22.0      1      0
# 1          1       1  female  38.0      1      0
# 2          1       3  female  26.0      0      0
# 3          1       1  female  35.0      1      0
# 4          0       3    male  35.0      0      0
# 5          0       3    male   NaN      0      0
# 6          0       1    male  54.0      0      0
# 7          0       3    male   2.0      3      1
# 8          1       3  female  27.0      0      2
# 9          1       2  female  14.0      1      0
# 10         1       3  female   4.0      1      1
# 11         1       1  female  58.0      0      0
# 12         0       3    male  20.0      0      0
# 13         0       3    male  39.0      1      5
# 14         0       3  female  14.0      0      0

# %%
#examine the trining data to determine how to deal with empty data
train.describe(include="all")
# Out:
#           Survived      Pclass   Sex         Age       SibSp       Parch
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000

# %%
#Fill the missing age with the mean age
train["Age"].fillna(train["Age"].mean(), inplace=True)
train.head(10)
# Out:
#    Survived  Pclass     Sex        Age  SibSp  Parch
# 0         0       3    male  22.000000      1      0
# 1         1       1  female  38.000000      1      0
# 2         1       3  female  26.000000      0      0
# 3         1       1  female  35.000000      1      0
# 4         0       3    male  35.000000      0      0
# 5         0       3    male  29.699118      0      0
# 6         0       1    male  54.000000      0      0
# 7         0       3    male   2.000000      3      1
# 8         1       3  female  27.000000      0      2
# 9         1       2  female  14.000000      1      0

# %%
#replace sex with numeric values for other ML models
#train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
#train.head(10)

# %%
#Double check for presence of null values
print(pd.isnull(train).sum())
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# dtype: int64

# %%
# count : Sex (to get a general idea of passengers by sex)
train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# count : Passenger class (to get a general idea of passengers by class)
train.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# My Initial observations
#
# Likely to survive; Women, Infants/children, Passengers with higher socioeconomic class
#
# Unlikely to survive; Men & Low socio economic class passengers

# %%
#bar plot of survival by sex
sns.barplot(x="Sex", y="Survived", data=train)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
#bar plot of survival by Passenger class
sns.barplot(x="Pclass", y="Survived", data=train)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
# Use histogram to visualize the age distribution 
train.Age.plot(kind='hist', title='Passenger Age Distribution', color='c');

# %%
#sort the ages into logical categories

bins = [0, 12, 18, 60, np.inf]
labels = ['Child', 'Teenager', 'Adult', 'Senior']
train['AgeGroup'] = pd.cut(train["Age"], bins, labels = labels)

#draw a bar plot of Age groups vs. survival
sns.barplot(x="AgeGroup", y="Survived", data=train)
plt.show()
